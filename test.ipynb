# %%
Barcode= "101-Ba0005-31.07.25-F-1-G1-8-Dasu300-Hnd-789"

# %%
list =Barcode.split("-")

# %%
list
# Out:
# ['101', 'Ba0005', '31.07.25', 'F', '1', 'G1', '8', 'Dasu300', 'Hnd', '789']

# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 4.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.0 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.0 MB 4.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.0 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.0 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/11.0 MB 4.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.0 MB 4.6 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 4.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame([list], columns=['Stowage', 'FlightNo', 'OrderDate', 'DACS_CLASS', 'Leg', 'Gally', 'BlockNo', 'ContainerCode', 'DES', 'DACS_ACType'])

# %%
df
# Out:
#   Stowage FlightNo OrderDate DACS_CLASS Leg Gally BlockNo ContainerCode  DES  \
# 0     101   Ba0005  31.07.25          F   1    G1       8       Dasu300  Hnd
#
#   DACS_ACType
# 0         789

# %%
Barcode_2 = "101-Ba0005-31.07.25-F-1-G1-8-Dasu300-Hnd-789 [EB1715_1|DPD061_4|DPD055_4|DPD1002_3|DG5069_4|DG5070_8|DPD056_16|DPD060_8|DPD053_8|DPF1210_1]"

# %%
def barcode_split(barcode):
    parts = barcode.split("-")
   
    return parts

# %%
barcode_split(Barcode_2)
# Out:
# ['101',
#  'Ba0005',
#  '31.07.25',
#  'F',
#  '1',
#  'G1',
#  '8',
#  'Dasu300',
#  'Hnd',
#  '789 [EB1715_1|DPD061_4|DPD055_4|DPD1002_3|DG5069_4|DG5070_8|DPD056_16|DPD060_8|DPD053_8|DPF1210_1]']
